# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
drop_columns = ['Електронна адреса', 'Результат', 'Прізвище(українською)', 
                'Ім`я (українською)', 'Електронна пошта',
               'Для груп ФІ-01 та ФІ-02: Тема диплому (приблизна)',
               'Для груп ФІ-01 та ФІ-02: Потенційний керівник диплому',
       'Для груп ФІ-01 та ФІ-02: Чи погоджена тема з керівником?']

# %%
ans_data = pd.read_csv("mkr_answers.csv")
ans_data.drop(columns = drop_columns)
# Out:
#           Позначка часу  Група  \
# 0   03.11.2023 11:24:21  ФІ-03
# 1   03.11.2023 12:03:38  ФБ-04
# 2   03.11.2023 12:15:17  ФБ-04
# 3   03.11.2023 12:45:09  ФБ-04
# 4   03.11.2023 12:48:03  ФБ-05
# ..                  ...    ...
# 91  03.11.2023 23:57:46  ФБ-04
# 92  03.11.2023 23:57:51  ФБ-04
# 93  04.11.2023 00:00:13  ФІ-02
# 94  04.11.2023 16:53:08  ФБ-05
# 95  05.11.2023 21:15:11  фе-01
#
#    Припустим, що ми навчили логістичну регресію. На новому прикладі х вона видає результат hθ(x)=0.4. Це означає (оберіть ВСІ релевантні варіанти)  \
# 0                      P(y=1|x;θ)=0.4, P(y=0|x;θ)=0.6
# 1                      P(y=1|x;θ)=0.4, P(y=0|x;θ)=0.6
# 2                      P(y=1|x;θ)=0.4, P(y=1|x;θ)=0.6
# 3                      P(y=0|x;θ)=0.6, P(y=1|x;θ)=0.4
# 4                      P(y=0|x;θ)=0.6, P(y=1|x;θ)=0.4
# ..                                                ...
# 91                     P(y=1|x;θ)=0.4, P(y=0|x;θ)=0.6
# ...
